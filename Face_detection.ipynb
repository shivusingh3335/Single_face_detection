# %%
from google.colab import drive
drive.mount('/Gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /Gdrive/

# %%
# %cd /Gdrive/My\ Drive/Colab\ Notebooks/image_reco
# Out:
# /Gdrive/My Drive/Colab Notebooks/image_reco

# %%
ls
# Out:
#  Face_detection.ipynb  'OpenCV Basic.ipynb'   pic2.jpg
#  obama.jpg              pic1.jpg              pic3.jpg

# %%
# !pip install face_recognition opencv-python cmake dlib
# Out:
# ...
#      |████████████████████████████████| 100.2MB 107kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566172 sha256=8453db5009c7cf6d903a6bfc6367b1ed1139e5cf8ecb792195d7c1a7f7d7f81b
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
import face_recognition
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("obama.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F46F001D3C8>

# %%
img= face_recognition.load_image_file("obama.jpg")

# %%
img
# Out:
# array([[[169, 175, 175],
#         [131, 132, 134],
#         [ 67,  61,  63],
#         ...,
#         [167, 175, 178],
#         [167, 175, 178],
#         [168, 176, 179]],
#
#        [[149, 154, 157],
#         [108, 109, 113],
#         [ 55,  49,  53],
#         ...,
#         [168, 176, 179],
#         [167, 175, 178],
#         [168, 176, 179]],
#
#        [[138, 143, 147],
#         [ 99, 100, 105],
#         [ 54,  49,  55],
#         ...,
#         [168, 176, 179],
#         [168, 176, 179],
#         [168, 176, 179]],
#
#        ...,
#
#        [[176,   0,   9],
#         [174,   1,   7],
#         [169,   3,   5],
#         ...,
#         [ 12,  15,  22],
#         [ 11,  14,  21],
#         [ 11,  14,  21]],
#
#        [[176,   0,   9],
#         [174,   1,   7],
#         [169,   3,   5],
#         ...,
#         [ 12,  15,  22],
#         [ 11,  14,  21],
#         [ 11,  14,  21]],
#
#        [[180,   2,   2],
#         [172,   4,   3],
#         [163,   8,   6],
# ...

# %%
loc = face_recognition.face_locations(image)

# %%
loc
# Out:
# [(44, 187, 152, 79)]

# %%
cv2.rectangle(image,(79,44),(187,152),(255,0,0),2)
cv2.putText(image,"Obama",(79,40),cv2.FONT_HERSHEY_SIMPLEX,0.8,(255,255,255),2)
# Out:
# array([[[177, 174, 170],
#         [134, 132, 132],
#         [ 65,  61,  67],
#         ...,
#         [178, 175, 167],
#         [178, 175, 167],
#         [179, 176, 168]],
#
#        [[157, 154, 150],
#         [113, 109, 108],
#         [ 53,  49,  55],
#         ...,
#         [179, 176, 168],
#         [178, 175, 167],
#         [179, 176, 168]],
#
#        [[147, 143, 138],
#         [104, 100,  99],
#         [ 55,  48,  55],
#         ...,
#         [179, 176, 168],
#         [179, 176, 168],
#         [179, 176, 168]],
#
#        ...,
#
#        [[  9,   0, 175],
#         [  7,   1, 172],
#         [  5,   4, 168],
#         ...,
#         [ 22,  15,  12],
#         [ 21,  14,  11],
#         [ 21,  14,  11]],
#
#        [[  7,   0, 175],
#         [  5,   2, 172],
#         [  5,   4, 168],
#         ...,
#         [ 22,  15,  12],
#         [ 21,  14,  11],
#         [ 21,  14,  11]],
#
#        [[  4,   3, 177],
#         [  4,   3, 173],
#         [  6,   6, 166],
# ...

# %%
cv2_imshow(image)
#cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F46DB29FB00>

# %%
features=face_recognition.face_landmarks(img)

# %%
features
# Out:
# [{'bottom_lip': [(152, 116),
#    (145, 121),
#    (139, 124),
#    (134, 125),
#    (129, 125),
#    (122, 122),
#    (115, 118),
#    (119, 119),
#    (129, 119),
#    (133, 119),
#    (138, 118),
#    (150, 117)],
#   'chin': [(91, 74),
#    (92, 85),
#    (94, 97),
#    (96, 108),
#    (100, 119),
#    (106, 130),
#    (114, 139),
#    (123, 147),
#    (135, 149),
#    (146, 146),
#    (156, 137),
#    (164, 128),
#    (170, 118),
#    (174, 107),
#    (177, 95),
#    (178, 83),
#    (179, 71)],
#   'left_eye': [(106, 75),
#    (111, 72),
#    (117, 71),
#    (121, 74),
#    (116, 75),
#    (111, 76)],
#   'left_eyebrow': [(97, 72), (102, 65), (110, 62), (118, 62), (127, 64)],
#   'nose_bridge': [(133, 71), (133, 80), (133, 88), (133, 96)],
#   'nose_tip': [(123, 102), (128, 103), (133, 104), (138, 102), (143, 101)],
#   'right_eye': [(146, 73),
#    (151, 70),
#    (156, 70),
#    (161, 72),
#    (157, 74),
#    (151, 74)],
# ...

# %%
known=face_recognition.load_image_file("obama.jpg")
unknown=face_recognition.load_image_file("donald.jpg")

# %%
known_enco=face_recognition.face_encodings(known)[0]
unknown_enco=face_recognition.face_encodings(unknown)[0]

# %%
known_enco
# Out:
# array([-0.07635106,  0.12730697,  0.08317646, -0.03936879, -0.00482912,
#        -0.01398583, -0.12342543, -0.08002824,  0.1693258 , -0.15446168,
#         0.24237314,  0.07088552, -0.21115839, -0.11833914,  0.05655752,
#         0.14634965, -0.24089414, -0.09080131, -0.10210288, -0.06861319,
#        -0.0064805 , -0.00583087,  0.09080227,  0.04833147, -0.10523868,
#        -0.39636031, -0.06982772, -0.15227708, -0.00831044, -0.17888968,
#        -0.10287072, -0.02481738, -0.17203544, -0.09368879, -0.02256165,
#        -0.00070696, -0.01600969, -0.02441767,  0.17970431,  0.04286344,
#        -0.1459111 ,  0.07407111, -0.00995667,  0.23025928,  0.26274401,
#         0.10464236,  0.03038291, -0.05772186,  0.14632143, -0.22230715,
#         0.05733592,  0.16217959,  0.08825481,  0.03305707,  0.09473399,
#        -0.18736288, -0.02011304,  0.0808323 , -0.08980019,  0.06404796,
#         0.06008815, -0.08029607,  0.0278187 ,  0.0606823 ,  0.18265438,
# ...

# %%
result=face_recognition.compare_faces([known_enco],unknown_enco)

# %%
result
# Out:
# [False]

# %%
known=face_recognition.load_image_file("test.jpg")
unknown=face_recognition.load_image_file("test3.jpg")
known_enco=face_recognition.face_encodings(known)[0]
unknown_enco=face_recognition.face_encodings(unknown)[0]

# %%
result=face_recognition.compare_faces([known_enco],unknown_enco)

# %%
result
# Out:
# [True]

# %%
distance=face_recognition.face_distance([known_enco],unknown_enco)

# %%
distance
# Out:
# array([0.48535826])
